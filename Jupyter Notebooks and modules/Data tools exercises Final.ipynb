# %% [markdown]
# # Exercise 1
# # title Data Science Tools and Ecosystem

# %%
# Exercise 2 - Create a markdown cell for an introduction
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# # Exercise 3
# # Some of the popular languages that Data Scientists use are: 1. Python, 2. R, 3. SQL
# Then create an ordered list (i.e. numbered) listing 3 (or more) commonly used languages for data science.

# %% [markdown]
# # Exercise 4 - Create a markdown cell to list data science libraries
#
# Ordered list is also refered as **numbered list**
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# # Exercise 5 - Create a markdown cell with a table of Data Science tools
#
# | **Data tools** | -**Programming Languages** | **Libraries** | **Visualization**      |
# |--------------- |--------------------------- |---------------|------------------------|
# |    1           |      Python                | Numpy Pandas  |       Matplotlib       |
# |    2           |      R                     |    pid        |    ggplot, plty        |

# %% [markdown]
# # Exercise 6 - Create a markdown cell introducing arithmetic expression examples
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# Exercise 7 - Create a code cell to multiply and add numbers
# This a simple arithmetic expression to mutiply then add integers.
(3*4)+5
# Out:
# 17

# %%
# Exercise 8 - Create a code cell to convert minutes to hours
# This will convert 200 minutes to hours by diving by 60.

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# # Exercise 9 - Insert a markdown cell to list Objectives
#
# **Objectives**
# # In this notebook, Data Science Tools and Ecosystem are summarized
#
# List popular languages for Data Science list (bullets) indicate
# * Python
# * R
# * SQL
# * Java
#
# An unordered list is also referred to as a **bulleted list**.
#
# You can create an unordered list by adding **plus signs (+)** in front of line items.

# %% [markdown]
# # Exercise 10 - Create a markdown cell to indicate the Author's name
# ## Author: Prem Kumar Seelam
# ## Date: January 5, 2026
